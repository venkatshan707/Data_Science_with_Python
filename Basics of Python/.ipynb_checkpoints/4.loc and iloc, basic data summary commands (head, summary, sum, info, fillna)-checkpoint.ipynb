# %%
import pandas as pd

# %%
df_ex_DemandData = pd.read_excel("Staff.xlsx", sheet_name="DemandData")
df_ex_DemandData
# https://github.com/ingledarshan/BoardInfinity/blob/main/Staffing%20Data.xlsx
# Out:
#    State Month  Demand
# 0      A   Jan    5240
# 1      A   Feb    4878
# 2      A   Mar    5942
# 3      A   Apr    2297
# 4      A   May    1992
# 5      A   Jun    2275
# 6      A   Jul    5334
# 7      A   Aug    3371
# 8      A   Sep    3759
# 9      A   Oct    3529
# 10     A   Nov    4284
# 11     A   Dec    5183
# 12     B   Jan    4927
# 13     B   Feb    2628
# 14     B   Mar    2974
# 15     B   Apr    2338
# 16     B   May    4020
# 17     B   Jun    3147
# 18     B   Jul    4271
# 19     B   Aug    2620
# 20     B   Sep    4517
# 21     B   Oct    4155
# 22     B   Nov    3137
# 23     B   Dec    4227
# 24     C   Jan    1162
# 25     C   Feb    1967
# 26     C   Mar    1898
# 27     C   Apr    2261
# 28     C   May    2030
# 29     C   Jun    1642
# 30     C   Jul    2489
# 31     C   Aug    2496
# 32     C   Sep     922
# 33     C   Oct    2421
# 34     C   Nov     963
# 35     C   Dec    1998

# %%
df_ex_StaffAvailability = pd.read_excel("Staff.xlsx", sheet_name="StaffAvailability")
df_ex_StaffAvailability
# Out:
#    State Month    LB    UB  StaffAvPer
# 0      A   Jan  0.70  0.90        0.81
# 1      A   Feb  0.65  0.85        0.76
# 2      A   Mar  0.70  0.80        0.75
# 3      A   Apr  0.75  0.85        0.80
# 4      A   May  0.70  0.85        0.78
# 5      A   Jun  0.65  0.80        0.73
# 6      A   Jul  0.60  0.75        0.68
# 7      A   Aug  0.65  0.85        0.76
# 8      A   Sep  0.70  0.90        0.81
# 9      A   Oct  0.65  0.80        0.73
# 10     A   Nov  0.60  0.75        0.68
# 11     A   Dec  0.60  0.70        0.65
# 12     B   Jan  0.70  0.90        0.81
# 13     B   Feb  0.65  0.85        0.76
# 14     B   Mar  0.70  0.80        0.75
# 15     B   Apr  0.75  0.85        0.80
# 16     B   May  0.70  0.85        0.78
# 17     B   Jun  0.65  0.80        0.73
# 18     B   Jul  0.60  0.75        0.68
# 19     B   Aug  0.65  0.85        0.76
# 20     B   Sep  0.70  0.90        0.81
# 21     B   Oct  0.65  0.80        0.73
# 22     B   Nov  0.60  0.75        0.68
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ingledarshan/BoardInfinity/main/student_records.csv")
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/ingledarshan/BoardInfinity/main/titanic.csv")
titanic.shape
# Out:
# (891, 12)

# %%
pd.Series(['a','b','c'])
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %% [markdown]
# # Indexers: loc and iloc

# %%
data = pd.Series(['a','b','c'], index=[1,3,5])
data
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
# explicit index when indexing
data[1]
# Out:
# 'a'

# %%
# implicit index when slicing
data[1:3]
# SI=1, EI=3-1
# Out:
# 3    b
# 5    c
# dtype: object

# %%
data.iloc[1]
# Out:
# 'b'

# %%
data.loc[1]
# Out:
# 'a'

# %%
data.iloc[1:3]
# SI=1, EI=3-1
# Out:
# 3    b
# 5    c
# dtype: object

# %%
data.loc[1:3]

# SI=1, EI=3
# Out:
# 1    a
# 3    b
# dtype: object

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
df.shape
# Out:
# (8, 6)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head() # display top 5 records
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.head(2) # display top 5 records
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
titanic.tail() # display bottom 5 records
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.tail(8) # display bottom 5 records
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 883    male  28.0      0      0  C.A./SOTON 34068  10.500   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.050   NaN        S
# ...

# %%
# https://raw.githubusercontent.com/ingledarshan/BK_Birla/main/input.json
import json

with open('input.json') as f:
  data = json.load(f)

# Output: {'name': 'Bob', 'languages': ['English', 'Fench']}
print(data)
# Out:
# {'ID': ['1', '2', '3', '4', '5', '6', '7', '8'], 'Name': ['Rick', 'Dan', 'Michelle', 'Ryan', 'Gary', 'Nina', 'Simon', 'Guru'], 'Salary': ['623.3', '515.2', '611', '729', '843.25', '578', '632.8', '722.5'], 'StartDate': ['1/1/2012', '9/23/2013', '11/15/2014', '5/11/2014', '3/27/2015', '5/21/2013', '7/30/2013', '6/17/2014'], 'Dept': ['IT', 'Operations', 'IT', 'HR', 'Finance', 'IT', 'Operations', 'Finance']}

# %%
type(data)
# Out:
# dict

# %%
pd.DataFrame(data)
# Out:
#   ID      Name  Salary   StartDate        Dept
# 0  1      Rick   623.3    1/1/2012          IT
# 1  2       Dan   515.2   9/23/2013  Operations
# 2  3  Michelle     611  11/15/2014          IT
# 3  4      Ryan     729   5/11/2014          HR
# 4  5      Gary  843.25   3/27/2015     Finance
# 5  6      Nina     578   5/21/2013          IT
# 6  7     Simon   632.8   7/30/2013  Operations
# 7  8      Guru   722.5   6/17/2014     Finance

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
df['OverallGrade']
# Out:
# 0    A
# 1    C
# 2    F
# 3    B
# 4    E
# 5    A
# 6    B
# 7    C
# Name: OverallGrade, dtype: object

# %%
df.OverallGrade
# Out:
# 0    A
# 1    C
# 2    F
# 3    B
# 4    E
# 5    A
# 6    B
# 7    C
# Name: OverallGrade, dtype: object

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
df.OverallGrade.unique()
# Out:
# array(['A', 'C', 'F', 'B', 'E'], dtype=object)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.Sex.unique()
# https://www.ducksters.com/history/us_1900s/titanic.php
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic.Pclass.unique()
# Out:
# array([3, 1, 2])

# %%
titanic['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
titanic.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic.Pclass.value_counts(normalize=True)
# Out:
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: Pclass, dtype: float64

# %%
titanic.Pclass.value_counts(normalize=True)*100
# Out:
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: Pclass, dtype: float64

# %%
titanic.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic.Embarked.value_counts(normalize=True)*100
# Out:
# S    72.440945
# C    18.897638
# Q     8.661417
# Name: Embarked, dtype: float64

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
# Summary of all numeric columns

df.describe()
# Out:
#        ResearchScore  ProjectScore
# count       8.000000      8.000000
# mean       63.375000     53.125000
# std        31.640559     24.752705
# min        10.000000     17.000000
# 25%        50.000000     32.250000
# 50%        75.000000     55.000000
# 75%        86.250000     73.000000
# max        92.000000     85.000000

# %%
# Summary of all columns

df.describe(include='all')
# Out:
#          Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# count       8            8        8       8.000000      8.000000         8
# unique      8            5        2            NaN           NaN         2
# top     Henry            C        Y            NaN           NaN        No
# freq        1            2        5            NaN           NaN         5
# mean      NaN          NaN      NaN      63.375000     53.125000       NaN
# std       NaN          NaN      NaN      31.640559     24.752705       NaN
# min       NaN          NaN      NaN      10.000000     17.000000       NaN
# 25%       NaN          NaN      NaN      50.000000     32.250000       NaN
# 50%       NaN          NaN      NaN      75.000000     55.000000       NaN
# 75%       NaN          NaN      NaN      86.250000     73.000000       NaN
# max       NaN          NaN      NaN      92.000000     85.000000       NaN

# %%
# Extract numerical columns

num_cols = df.describe().columns
num_cols = list(num_cols)
num_cols
# Out:
# ['ResearchScore', 'ProjectScore']

# %%
df[num_cols]
# Out:
#    ResearchScore  ProjectScore
# 0             90            85
# 1             85            51
# 2             10            17
# 3             75            71
# 4             20            30
# 5             92            79
# 6             60            59
# 7             75            33

# %%
# Extract all Categorical columns

# df.columns -> all columns

# df.describe().columns -> all numerical columns

cat_cols = set(df.columns) - set(df.describe().columns)
cat_cols
# Out:
# {'Name', 'Obedient', 'OverallGrade', 'Recommend'}

# %%
df[cat_cols]
# Out:
#   Obedient Recommend    Name OverallGrade
# 0        Y       Yes   Henry            A
# 1        N       Yes    John            C
# 2        N        No   David            F
# 3        Y        No  Holmes            B
# 4        N        No  Marvin            E
# 5        Y       Yes   Simon            A
# 6        Y        No  Robert            B
# 7        Y        No   Trent            C

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           8 non-null      object
#  1   OverallGrade   8 non-null      object
#  2   Obedient       8 non-null      object
#  3   ResearchScore  8 non-null      int64
#  4   ProjectScore   8 non-null      int64
#  5   Recommend      8 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 512.0+ bytes

# %%
# Extract numerical columns

numcol = df.select_dtypes(include=['int','float'])
numcol
# Out:
#    ResearchScore  ProjectScore
# 0             90            85
# 1             85            51
# 2             10            17
# 3             75            71
# 4             20            30
# 5             92            79
# 6             60            59
# 7             75            33

# %%
# Extract numerical columns

numcol = df.select_dtypes(exclude=['object'])
numcol
# Out:
#    ResearchScore  ProjectScore
# 0             90            85
# 1             85            51
# 2             10            17
# 3             75            71
# 4             20            30
# 5             92            79
# 6             60            59
# 7             75            33

# %%
# Extract categorical columns

catcol = df.select_dtypes(exclude=['int','float'])
catcol
# Out:
#      Name OverallGrade Obedient Recommend
# 0   Henry            A        Y       Yes
# 1    John            C        N       Yes
# 2   David            F        N        No
# 3  Holmes            B        Y        No
# 4  Marvin            E        N        No
# 5   Simon            A        Y       Yes
# 6  Robert            B        Y        No
# 7   Trent            C        Y        No

# %%
# Extract categorical columns

catcol = df.select_dtypes(include=['object'])
catcol
# Out:
#      Name OverallGrade Obedient Recommend
# 0   Henry            A        Y       Yes
# 1    John            C        N       Yes
# 2   David            F        N        No
# 3  Holmes            B        Y        No
# 4  Marvin            E        N        No
# 5   Simon            A        Y       Yes
# 6  Robert            B        Y        No
# 7   Trent            C        Y        No

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
df['Obedient']
# Out:
# 0    Y
# 1    N
# 2    N
# 3    Y
# 4    N
# 5    Y
# 6    Y
# 7    Y
# Name: Obedient, dtype: object

# %%
df.Obedient
# Out:
# 0    Y
# 1    N
# 2    N
# 3    Y
# 4    N
# 5    Y
# 6    Y
# 7    Y
# Name: Obedient, dtype: object

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
df[ ['OverallGrade','Recommend'] ]
# Out:
#   OverallGrade Recommend
# 0            A       Yes
# 1            C       Yes
# 2            F        No
# 3            B        No
# 4            E        No
# 5            A       Yes
# 6            B        No
# 7            C        No

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
x = df[['ResearchScore','ProjectScore']]
x
# Out:
#    ResearchScore  ProjectScore
# 0             90            85
# 1             85            51
# 2             10            17
# 3             75            71
# 4             20            30
# 5             92            79
# 6             60            59
# 7             75            33

# %%
x.sum()
# Out:
# ResearchScore    507
# ProjectScore     425
# dtype: int64

# %%
x.sum(axis=0) # default axis=0
# Out:
# ResearchScore    507
# ProjectScore     425
# dtype: int64

# %%
x.sum(axis=1)
# Out:
# 0    175
# 1    136
# 2     27
# 3    146
# 4     50
# 5    171
# 6    119
# 7    108
# dtype: int64

# %%
x.mean(axis=0)
# Out:
# ResearchScore    63.375
# ProjectScore     53.125
# dtype: float64

# %%
x.mean(axis=1)
# Out:
# 0    87.5
# 1    68.0
# 2    13.5
# 3    73.0
# 4    25.0
# 5    85.5
# 6    59.5
# 7    54.0
# dtype: float64

# %%
x.median(axis=0)
# Out:
# ResearchScore    75.0
# ProjectScore     55.0
# dtype: float64

# %%
x.describe()
# Out:
#        ResearchScore  ProjectScore
# count       8.000000      8.000000
# mean       63.375000     53.125000
# std        31.640559     24.752705
# min        10.000000     17.000000
# 25%        50.000000     32.250000
# 50%        75.000000     55.000000
# 75%        86.250000     73.000000
# max        92.000000     85.000000

# %%
x.max(axis=0)
# Out:
# ResearchScore    92
# ProjectScore     85
# dtype: int64

# %%
x.max(axis=1)
# Out:
# 0    90
# 1    85
# 2    17
# 3    75
# 4    30
# 5    92
# 6    60
# 7    75
# dtype: int64

# %%
x
# Out:
#    ResearchScore  ProjectScore
# 0             90            85
# 1             85            51
# 2             10            17
# 3             75            71
# 4             20            30
# 5             92            79
# 6             60            59
# 7             75            33

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
x['TotalScore'] = 0
x
# Out:
#    ResearchScore  ProjectScore  TotalScore
# 0             90            85           0
# 1             85            51           0
# 2             10            17           0
# 3             75            71           0
# 4             20            30           0
# 5             92            79           0
# 6             60            59           0
# 7             75            33           0

# %%
x.drop(['TotalScore'], axis=1)
# Out:
#    ResearchScore  ProjectScore
# 0             90            85
# 1             85            51
# 2             10            17
# 3             75            71
# 4             20            30
# 5             92            79
# 6             60            59
# 7             75            33

# %%
x
# Out:
#    ResearchScore  ProjectScore  TotalScore
# 0             90            85           0
# 1             85            51           0
# 2             10            17           0
# 3             75            71           0
# 4             20            30           0
# 5             92            79           0
# 6             60            59           0
# 7             75            33           0

# %%
# x = x.drop(['TotalScore'], axis=1)
# OR
x.drop(['TotalScore'], axis=1, inplace=True)

# %%
x
# Out:
#    ResearchScore  ProjectScore
# 0             90            85
# 1             85            51
# 2             10            17
# 3             75            71
# 4             20            30
# 5             92            79
# 6             60            59
# 7             75            33

# %%
x['TotalScore'] = x['ResearchScore'] + x['ProjectScore']
x
# Out:
#    ResearchScore  ProjectScore  TotalScore
# 0             90            85         175
# 1             85            51         136
# 2             10            17          27
# 3             75            71         146
# 4             20            30          50
# 5             92            79         171
# 6             60            59         119
# 7             75            33         108

# %%
x['Percentage'] = (x['TotalScore']/200)*100
x
# Out:
#    ResearchScore  ProjectScore  TotalScore  Percentage
# 0             90            85         175        87.5
# 1             85            51         136        68.0
# 2             10            17          27        13.5
# 3             75            71         146        73.0
# 4             20            30          50        25.0
# 5             92            79         171        85.5
# 6             60            59         119        59.5
# 7             75            33         108        54.0

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ResearchScore  8 non-null      int64
#  1   ProjectScore   8 non-null      int64
#  2   TotalScore     8 non-null      int64
#  3   Percentage     8 non-null      float64
# dtypes: float64(1), int64(3)
# memory usage: 384.0 bytes

# %%
import numpy as np
x['Percentage'] = np.round(x['Percentage'])
x
# Out:
#    ResearchScore  ProjectScore  TotalScore  Percentage
# 0             90            85         175        88.0
# 1             85            51         136        68.0
# 2             10            17          27        14.0
# 3             75            71         146        73.0
# 4             20            30          50        25.0
# 5             92            79         171        86.0
# 6             60            59         119        60.0
# 7             75            33         108        54.0

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ResearchScore  8 non-null      int64
#  1   ProjectScore   8 non-null      int64
#  2   TotalScore     8 non-null      int64
#  3   Percentage     8 non-null      float64
# dtypes: float64(1), int64(3)
# memory usage: 384.0 bytes

# %%
x['Percentage'] = x['Percentage'].astype('int')
x
# Out:
#    ResearchScore  ProjectScore  TotalScore  Percentage
# 0             90            85         175          88
# 1             85            51         136          68
# 2             10            17          27          14
# 3             75            71         146          73
# 4             20            30          50          25
# 5             92            79         171          86
# 6             60            59         119          60
# 7             75            33         108          54

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ResearchScore  8 non-null      int64
#  1   ProjectScore   8 non-null      int64
#  2   TotalScore     8 non-null      int64
#  3   Percentage     8 non-null      int64
# dtypes: int64(4)
# memory usage: 384.0 bytes

# %%
x.to_csv("Shiva.csv")
print("File saved successfully.")
# Out:
# File saved successfully.

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
df['OverallGrade'][0]
# Out:
# 'A'

# %%
df.ResearchScore[4]
# Out:
# 20

# %%
df['ResearchScore'][4]
# Out:
# 20

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
df.iloc[0][0]
# Out:
# 'Henry'

# %%
df.iloc[7][5]
# Out:
# 'No'

# %%
df.iloc[3][3]
# Out:
# 75

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
df.iloc[ 0:5 , 0:2 ]
# Out:
#      Name OverallGrade
# 0   Henry            A
# 1    John            C
# 2   David            F
# 3  Holmes            B
# 4  Marvin            E

# %%
df.iloc[ :5 , :2 ]
# Out:
#      Name OverallGrade
# 0   Henry            A
# 1    John            C
# 2   David            F
# 3  Holmes            B
# 4  Marvin            E

# %%
df.columns
# Out:
# Index(['Name', 'OverallGrade', 'Obedient', 'ResearchScore', 'ProjectScore',
#        'Recommend'],
#       dtype='object')

# %%
# Convert my dataframe to numpy array
np_arr_df = df.values
np_arr_df
# Out:
# array([['Henry', 'A', 'Y', 90, 85, 'Yes'],
#        ['John', 'C', 'N', 85, 51, 'Yes'],
#        ['David', 'F', 'N', 10, 17, 'No'],
#        ['Holmes', 'B', 'Y', 75, 71, 'No'],
#        ['Marvin', 'E', 'N', 20, 30, 'No'],
#        ['Simon', 'A', 'Y', 92, 79, 'Yes'],
#        ['Robert', 'B', 'Y', 60, 59, 'No'],
#        ['Trent', 'C', 'Y', 75, 33, 'No']], dtype=object)

# %%
type(np_arr_df)
# Out:
# numpy.ndarray

# %%
pd.DataFrame(np_arr_df, columns=['Name', 'OverallGrade', 'Obedient', 'ResearchScore', 'ProjectScore',
       'Recommend'])
# Out:
#      Name OverallGrade Obedient ResearchScore ProjectScore Recommend
# 0   Henry            A        Y            90           85       Yes
# 1    John            C        N            85           51       Yes
# 2   David            F        N            10           17        No
# 3  Holmes            B        Y            75           71        No
# 4  Marvin            E        N            20           30        No
# 5   Simon            A        Y            92           79       Yes
# 6  Robert            B        Y            60           59        No
# 7   Trent            C        Y            75           33        No

# %%
from numpy import nan
# nan - not a number
df.iloc[1,1] = nan
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John          NaN        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
df['OverallGrade'].fillna('E', inplace=True)
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            E        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            33        No

# %%
df.iloc[1,3] = nan
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y           90.0            85       Yes
# 1    John            E        N            NaN            51       Yes
# 2   David            F        N           10.0            17        No
# 3  Holmes            B        Y           75.0            71        No
# 4  Marvin            E        N           20.0            30        No
# 5   Simon            A        Y           92.0            79       Yes
# 6  Robert            B        Y           60.0            59        No
# 7   Trent            C        Y           75.0            33        No

# %%
df['ResearchScore'].fillna(0, inplace=True)
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y           90.0            85       Yes
# 1    John            E        N            0.0            51       Yes
# 2   David            F        N           10.0            17        No
# 3  Holmes            B        Y           75.0            71        No
# 4  Marvin            E        N           20.0            30        No
# 5   Simon            A        Y           92.0            79       Yes
# 6  Robert            B        Y           60.0            59        No
# 7   Trent            C        Y           75.0            33        No

# %%
df.iloc[1,3] = nan
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y           90.0            85       Yes
# 1    John            E        N            NaN            51       Yes
# 2   David            F        N           10.0            17        No
# 3  Holmes            B        Y           75.0            71        No
# 4  Marvin            E        N           20.0            30        No
# 5   Simon            A        Y           92.0            79       Yes
# 6  Robert            B        Y           60.0            59        No
# 7   Trent            C        Y           75.0            33        No

# %%
df.ResearchScore.mean()
# Out:
# 60.285714285714285

# %%
df.ResearchScore.fillna(df.ResearchScore.mean(), inplace=True)
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y      90.000000            85       Yes
# 1    John            E        N      60.285714            51       Yes
# 2   David            F        N      10.000000            17        No
# 3  Holmes            B        Y      75.000000            71        No
# 4  Marvin            E        N      20.000000            30        No
# 5   Simon            A        Y      92.000000            79       Yes
# 6  Robert            B        Y      60.000000            59        No
# 7   Trent            C        Y      75.000000            33        No

# %%
df.iloc[1,1] = nan
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y      90.000000            85       Yes
# 1    John          NaN        N      60.285714            51       Yes
# 2   David            F        N      10.000000            17        No
# 3  Holmes            B        Y      75.000000            71        No
# 4  Marvin            E        N      20.000000            30        No
# 5   Simon            A        Y      92.000000            79       Yes
# 6  Robert            B        Y      60.000000            59        No
# 7   Trent            C        Y      75.000000            33        No

# %%
df.OverallGrade.fillna(method='ffill', inplace=True)
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y      90.000000            85       Yes
# 1    John            A        N      60.285714            51       Yes
# 2   David            F        N      10.000000            17        No
# 3  Holmes            B        Y      75.000000            71        No
# 4  Marvin            E        N      20.000000            30        No
# 5   Simon            A        Y      92.000000            79       Yes
# 6  Robert            B        Y      60.000000            59        No
# 7   Trent            C        Y      75.000000            33        No

# %%
df.iloc[1,1] = nan
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y      90.000000            85       Yes
# 1    John          NaN        N      60.285714            51       Yes
# 2   David            F        N      10.000000            17        No
# 3  Holmes            B        Y      75.000000            71        No
# 4  Marvin            E        N      20.000000            30        No
# 5   Simon            A        Y      92.000000            79       Yes
# 6  Robert            B        Y      60.000000            59        No
# 7   Trent            C        Y      75.000000            33        No

# %%
df.OverallGrade.fillna(method='bfill', inplace=True)
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y      90.000000            85       Yes
# 1    John            F        N      60.285714            51       Yes
# 2   David            F        N      10.000000            17        No
# 3  Holmes            B        Y      75.000000            71        No
# 4  Marvin            E        N      20.000000            30        No
# 5   Simon            A        Y      92.000000            79       Yes
# 6  Robert            B        Y      60.000000            59        No
# 7   Trent            C        Y      75.000000            33        No

# %%
df.iloc[1,1] = nan
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y      90.000000            85       Yes
# 1    John          NaN        N      60.285714            51       Yes
# 2   David            F        N      10.000000            17        No
# 3  Holmes            B        Y      75.000000            71        No
# 4  Marvin            E        N      20.000000            30        No
# 5   Simon            A        Y      92.000000            79       Yes
# 6  Robert            B        Y      60.000000            59        No
# 7   Trent            C        Y      75.000000            33        No

# %%
df.OverallGrade.mode()[0]
# Out:
# 'A'

# %%
df.OverallGrade.fillna(df.OverallGrade.mode()[0], inplace=True)
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y      90.000000            85       Yes
# 1    John            A        N      60.285714            51       Yes
# 2   David            F        N      10.000000            17        No
# 3  Holmes            B        Y      75.000000            71        No
# 4  Marvin            E        N      20.000000            30        No
# 5   Simon            A        Y      92.000000            79       Yes
# 6  Robert            B        Y      60.000000            59        No
# 7   Trent            C        Y      75.000000            33        No

# %% [markdown]
# # Happy Learning

# %%
df.iloc[3,2] = nan
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y      90.000000            85       Yes
# 1    John            A        N      60.285714            51       Yes
# 2   David            F        N      10.000000            17        No
# 3  Holmes            B      NaN      75.000000            71        No
# 4  Marvin            E        N      20.000000            30        No
# 5   Simon            A        Y      92.000000            79       Yes
# 6  Robert            B        Y      60.000000            59        No
# 7   Trent            C        Y      75.000000            33        No

# %%
df.Obedient.value_counts()
# Out:
# Y    4
# N    3
# Name: Obedient, dtype: int64

# %%
df.Obedient.mode()
# Out:
# 0    Y
# dtype: object

# %%
type(df.Obedient.mode())
# Out:
# pandas.core.series.Series

# %%
s = pd.Series([100,200,300])
s
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
s[0]
# Out:
# 100

# %%
df.Obedient.mode()[0]
# Out:
# 'Y'

# %%
df.Obedient.fillna(df.Obedient.mode()[0], inplace=True)
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y      90.000000            85       Yes
# 1    John            A        N      60.285714            51       Yes
# 2   David            F        N      10.000000            17        No
# 3  Holmes            B        Y      75.000000            71        No
# 4  Marvin            E        N      20.000000            30        No
# 5   Simon            A        Y      92.000000            79       Yes
# 6  Robert            B        Y      60.000000            59        No
# 7   Trent            C        Y      75.000000            33        No
